# %% [markdown]
# # Machine Learning For Finance
#
# #### Course reference:Machine Learning For Finance by Krishnendu chakraborty
# #### Topics covered: Financial data understanding, EDA(Exploratory data analysis) and feature engineering
# #### Author: Mayuri.A (MSc Statistics @ Christ university Bangalore )
# #### Date:18-09-23
# #### Dataset-Google 10 year weekly dataset 2013-2023
# #### Subtopic: Stock Data Analysis

# %% [markdown]
# ######  We are using the Kaggle online dataset - Google stock data set available at https://www.kaggle.com/datasets/r1shabhgupta/google-stock-price-daily-weekly-and-monthly-2023
# ###### let us utilize the available machine learning packages and statistical to deliver the maximum analysis.
# ###### note: close, high, open,low are prices that are recorded in dollars
#
# ### Objective:
#
# ##### STOCK DATA ANALYSIS
# ###### 1)Data Cleaning
# ###### 2) Descriptive statistics
# ###### 3) Univariate and Bivariate Data Analysis
# ###### 4)Outlier Detection
# ###### 5) Prepare Data for Modeling (Normalization),(Test and Train Dataset)

# %% [markdown]
# ### About The Dataset - Source (Kaggle)
# The Google Stock Price dataset contains historical price information for Google's stock, covering the period from March 2013 to the present. The dataset is made up of seven columns, each providing unique information about Google's stock performance.
#
# The first column is the 'date' column, which provides the date on which the stock price was recorded. The second column is the 'price' column, which displays the opening price of the stock on the given date. The third column is the 'high' column, which represents the highest price at which the stock was traded during the day. The fourth column is the 'low' column, which displays the lowest price at which the stock was traded during the day.
#
# The fifth column is the 'close' column, which represents the closing price of the stock on the given date. The sixth column is the 'volume' column, which displays the total number of shares traded on the given date. The final column is the 'adj close' column, which displays the adjusted closing price of the stock on the given date.
#
# The dataset provides a wealth of information for investors and analysts looking to gain insights into Google's stock performance. By analyzing the data over time, users can identify patterns and trends, evaluate the impact of external factors on stock price, and make informed investment decisions.
#
# The dataset is ideal for conducting advanced data analysis, including regression analysis, time series analysis, and predictive modeling. It can also be used to create informative visualizations, such as line graphs and candlestick charts, to better understand trends and patterns in Google's stock performance.

# %%
# Let us import the dataset from the internal storage
#Import dataset
import numpy as np
import pandas as pd
x=pd.read_csv('C:/Users/mayur/Desktop/Mstat/projects/Springboard/Machine learning for Finance/GW10YR1.csv')
x
# Out:
#      year  Month   Price    High    Low   Close     Volume  Adj Close
# 0    2013      4   19.67   20.11  19.05   20.02  613697688      20.02
# 1    2013      4   20.04   20.47  19.39   20.06  458928612      20.06
# 2    2013      4   20.10   21.19  20.10   21.16  423312264      21.16
# 3    2013      5   21.23   22.04  21.23   22.03  426249324      22.03
# 4    2013      5   21.99   23.02  21.86   22.75  520091388      22.75
# ..    ...    ...     ...     ...    ...     ...        ...        ...
# 515  2023      2   89.87   93.73  89.32   93.65  156120000      93.65
# 516  2023      3   94.02   95.97  90.40   90.63  159332600      90.63
# 517  2023      3   90.09  102.84  89.42  101.62  250528400     101.62
# 518  2023      3  100.12  106.59  99.87  105.44  189706900     105.44
# 519  2023      3  104.62  104.76  99.74  103.73  161867800     103.73
#
# [520 rows x 8 columns]

# %%
# to know the first 5 rows and last 5 rows.
x.head()
# Out:
#    year  Month  Price   High    Low  Close     Volume  Adj Close
# 0  2013      4  19.67  20.11  19.05  20.02  613697688      20.02
# 1  2013      4  20.04  20.47  19.39  20.06  458928612      20.06
# 2  2013      4  20.10  21.19  20.10  21.16  423312264      21.16
# 3  2013      5  21.23  22.04  21.23  22.03  426249324      22.03
# 4  2013      5  21.99  23.02  21.86  22.75  520091388      22.75

# %%
x.tail()
# Out:
#      year  Month   Price    High    Low   Close     Volume  Adj Close
# 515  2023      2   89.87   93.73  89.32   93.65  156120000      93.65
# 516  2023      3   94.02   95.97  90.40   90.63  159332600      90.63
# 517  2023      3   90.09  102.84  89.42  101.62  250528400     101.62
# 518  2023      3  100.12  106.59  99.87  105.44  189706900     105.44
# 519  2023      3  104.62  104.76  99.74  103.73  161867800     103.73

# %% [markdown]
# ## Data Cleaning

# %%
# It is important to remove all the columns or rows that are missing.
y=x.isnull()
y
# Out:
#       year  Month  Price   High    Low  Close  Volume  Adj Close
# 0    False  False  False  False  False  False   False      False
# 1    False  False  False  False  False  False   False      False
# 2    False  False  False  False  False  False   False      False
# 3    False  False  False  False  False  False   False      False
# 4    False  False  False  False  False  False   False      False
# ..     ...    ...    ...    ...    ...    ...     ...        ...
# 515  False  False  False  False  False  False   False      False
# 516  False  False  False  False  False  False   False      False
# 517  False  False  False  False  False  False   False      False
# 518  False  False  False  False  False  False   False      False
# 519  False  False  False  False  False  False   False      False
#
# [520 rows x 8 columns]

# %%
y=x.dropna()
y
# Out:
#      year  Month   Price    High    Low   Close     Volume  Adj Close
# 0    2013      4   19.67   20.11  19.05   20.02  613697688      20.02
# 1    2013      4   20.04   20.47  19.39   20.06  458928612      20.06
# 2    2013      4   20.10   21.19  20.10   21.16  423312264      21.16
# 3    2013      5   21.23   22.04  21.23   22.03  426249324      22.03
# 4    2013      5   21.99   23.02  21.86   22.75  520091388      22.75
# ..    ...    ...     ...     ...    ...     ...        ...        ...
# 515  2023      2   89.87   93.73  89.32   93.65  156120000      93.65
# 516  2023      3   94.02   95.97  90.40   90.63  159332600      90.63
# 517  2023      3   90.09  102.84  89.42  101.62  250528400     101.62
# 518  2023      3  100.12  106.59  99.87  105.44  189706900     105.44
# 519  2023      3  104.62  104.76  99.74  103.73  161867800     103.73
#
# [520 rows x 8 columns]

# %% [markdown]
# ## Descriptive Data Analysis

# %%
## the following code can be used when we want the summary statistics of only the numerical data 
##  the date here is a not a quantitative measure

x.describe(include = [np.number])
# Out:
#               year       Month       Price        High         Low  \
# count   520.000000  520.000000  520.000000  520.000000  520.000000
# mean   2017.759615    6.526923   61.356596   63.084558   59.804115
# std       2.900054    3.456201   34.375312   35.475469   33.264458
# min    2013.000000    1.000000   19.670000   20.110000   19.050000
# 25%    2015.000000    4.000000   34.315000   35.522500   33.272500
# 50%    2018.000000    7.000000   53.260000   54.775000   51.820000
# 75%    2020.000000   10.000000   77.825000   80.120000   75.572500
# max    2023.000000   12.000000  149.820000  151.550000  147.240000
#
#             Close        Volume   Adj Close
# count  520.000000  5.200000e+02  520.000000
# mean    61.589731  1.996413e+08   61.589731
# std     34.461334  1.013591e+08   34.461334
# min     20.020000  7.076200e+07   20.020000
# 25%     34.695000  1.358000e+08   34.695000
# 50%     53.430000  1.703130e+08   53.430000
# 75%     78.850000  2.301250e+08   78.850000
# ...

# %% [markdown]
# We observe that there has been a event/events that have shot up the price of the stock throughout. this pattern is observed for both the price(High/low/close) and the volume traded.
# this can be observed in the Q3(75%) of the data of price/volume lying still significantly lower than that of the max value that has been recorded in the past 10 years
# we can also expect perhaps stock splits/ economic shocks or boons that could be traced in the past 10 year data analysis.

# %% [markdown]
# ## UNIVARIATE AND BIVARIATE DATA ANALYSIS

# %%
# Filtering out closing price and volume
stock=y.loc[:,["year","Month","Close","Volume"]]
stock.head()
# Out:
#    year  Month  Close     Volume
# 0  2013      4  20.02  613697688
# 1  2013      4  20.06  458928612
# 2  2013      4  21.16  423312264
# 3  2013      5  22.03  426249324
# 4  2013      5  22.75  520091388

# %% [markdown]
# #### Take the last closing price and volume for each month

# %%
# we do not use average values
#since we might lose quality information

import numpy as np
stock_agg=stock.groupby(["year","Month"]).tail(1)
stock_agg.head()
# Out:
#     year  Month  Close     Volume
# 2   2013      4  21.16  423312264
# 6   2013      5  21.80  334105560
# 10  2013      6  22.03  466624908
# 15  2013      7  22.69  386545068
# 19  2013      8  21.19  297965736

# %%
#resetting index 
stock_agg=stock_agg.sort_values(by=["year","Month"],ascending=True).reset_index()
stock_agg.drop(axis=1,columns='index',inplace=True)
stock_agg.head()
# Out:
#    year  Month  Close     Volume
# 0  2013      4  21.16  423312264
# 1  2013      5  21.80  334105560
# 2  2013      6  22.03  466624908
# 3  2013      7  22.69  386545068
# 4  2013      8  21.19  297965736

# %%
#importing packages
import matplotlib.pyplot as plt
import seaborn as sbn
plt.ion()
plt.style.use('ggplot') # used in R

# %%
# Creating an year-month function (yrmo)
stock_agg["yrmo"] = stock_agg["year"].map(str)+stock_agg["Month"].map(str)
stock_agg.head()
# Out:
#    year  Month  Close     Volume   yrmo
# 0  2013      4  21.16  423312264  20134
# 1  2013      5  21.80  334105560  20135
# 2  2013      6  22.03  466624908  20136
# 3  2013      7  22.69  386545068  20137
# 4  2013      8  21.19  297965736  20138

# %%
# Plot cosing price vs time
def get_scatterplot(stock,yvar,ylim):
    fig = plt.figure(figsize=(20,10))
    for i,p in zip(range(4), range(0,120,30)):
        plt.subplot(221+i)
        plt.xticks(rotation=90)
        ax= sbn.lineplot(x="yrmo" , y=yvar, data=stock[p:p+30], sort=False)
        plt.xlabel("Year-Month")
        ax.set_ylim(ylim)

# %%
get_scatterplot(stock_agg,"Close",[0,700])
# Out:
# c:\Users\mayur\anaconda3\envs\talib\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mayur\anaconda3\envs\talib\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mayur\anaconda3\envs\talib\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## Lags, Moving Average and RSI Based Features

# %% [markdown]
# ### RSI -
# RSI indicator is a momentum indicator used in technical analysis (other:Fundamental analysis). ie, help us measure the speed and magnitude (slope) in the security price. and help us understand if the security is underpriced/overprices.
#
# -if RSI is near 0 that means the stock is over sold and is likely to rebound from its recent lows.
#
# -if the RSI is near 100 it means the stock is over bought and is likely to reverse to a downward trajectory.
#
# formula for RS = average gain over n periods/average loss over n periods.
#
# RSI = 100-(100/(1+RS))

# %%
for i in range(1,7):
    stock_agg['Close_lag'+str(i)] = stock_agg['Close'].shift(i)
stock_agg.head()
# Out:
#    year  Month  Close     Volume   yrmo  Close_lag1  Close_lag2  Close_lag3  \
# 0  2013      4  21.16  423312264  20134         NaN         NaN         NaN
# 1  2013      5  21.80  334105560  20135       21.16         NaN         NaN
# 2  2013      6  22.03  466624908  20136       21.80       21.16         NaN
# 3  2013      7  22.69  386545068  20137       22.03       21.80       21.16
# 4  2013      8  21.19  297965736  20138       22.69       22.03       21.80
#
#    Close_lag4  Close_lag5  Close_lag6
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4       21.16         NaN         NaN

# %%
import talib

# %%
for n in [3,6,9,12]:
    
    #Create the moving average and divide by the close price to average it out
    
    stock_agg['ma_'+str(n)]=talib.SMA(stock_agg['Close'].values,timeperiod=n)/stock_agg['Close']
    
    #Create the RSI indicator 
    stock_agg['rsi_'+str(n)]=talib.RSI(stock_agg['Close'].values,timeperiod=n)
stock_agg.head(10)
# Out:
#    year  Month  Close     Volume    yrmo  Close_lag1  Close_lag2  Close_lag3  \
# 0  2013      4  21.16  423312264   20134         NaN         NaN         NaN
# 1  2013      5  21.80  334105560   20135       21.16         NaN         NaN
# 2  2013      6  22.03  466624908   20136       21.80       21.16         NaN
# 3  2013      7  22.69  386545068   20137       22.03       21.80       21.16
# 4  2013      8  21.19  297965736   20138       22.69       22.03       21.80
# 5  2013      9  21.83  334764900   20139       21.19       22.69       22.03
# 6  2013     10  25.70  280163556  201310       21.83       21.19       22.69
# 7  2013     11  26.52  248379372  201311       25.70       21.83       21.19
# 8  2013     12  27.65  243040716  201312       26.52       25.70       21.83
# 9  2014      1  29.55  783271944   20141       27.65       26.52       25.70
#
#    Close_lag4  Close_lag5  Close_lag6      ma_3       rsi_3      ma_6  \
# ...

# %%
plt.figure(figsize=(14,8))
corr=stock_agg.drop(columns=['year','Month','yrmo']).corr()
sbn.heatmap(data=corr,annot=True,cmap='Wistia')
# Out:
# <Axes: >

# %% [markdown]
# The correlation heat map help us understand the relation between the different vectors/parameters/factors. here we are able to understang and visualize the nature of correlation between different time period which affect the close price. ie, the previous day's data points.

# %% [markdown]
# ##  Outliers Detection

# %% [markdown]
# We are intending to understand the data distributed across the inter-quantile range.Thus we will also find if there is any values that are away from the interquartiles (outliers) and eliminate them as needed.

# %%
#Compute IQR
Q1 = stock[["Close","Volume"]].quantile(0.25)
Q3 = stock[["Close","Volume"]].quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# Close     4.415500e+01
# Volume    9.432500e+07
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sbn
plt.style.use('ggplot')

# %%
plt.boxplot("Close", data=stock_agg)     # Visualization
plt.xscale("log")

# %% [markdown]
# Here we observe we have outliers and thus need to be handled

# %%
plt.boxplot('Volume',data=stock_agg)  # Visualization
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x211d2304fa0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x211d2305420>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x211d2304d00>],
#  'medians': [<matplotlib.lines.Line2D at 0x211d2305960>],
#  'fliers': [<matplotlib.lines.Line2D at 0x211d2305c00>],
#  'means': []}

# %%
stock_agg
# Out:
#      year  Month   Close     Volume    yrmo  Close_lag1  Close_lag2  \
# 0    2013      4   21.16  423312264   20134         NaN         NaN
# 1    2013      5   21.80  334105560   20135       21.16         NaN
# 2    2013      6   22.03  466624908   20136       21.80       21.16
# 3    2013      7   22.69  386545068   20137       22.03       21.80
# 4    2013      8   21.19  297965736   20138       22.69       22.03
# ..    ...    ...     ...        ...     ...         ...         ...
# 115  2022     11  100.44  140114500  202211       86.58       95.65
# 116  2022     12   88.23   86940300  202212      100.44       86.58
# 117  2023      1  104.78  227821100   20231       88.23      100.44
# 118  2023      2   93.65  156120000   20232      104.78       88.23
# 119  2023      3  103.73  161867800   20233       93.65      104.78
#
#      Close_lag3  Close_lag4  Close_lag5  Close_lag6
# 0           NaN         NaN         NaN         NaN
# ...

# %% [markdown]
# #### Addressing outliers for 'Close'

# %%
len(stock_agg[stock_agg.Close>Q3['Close']+1.5*IQR[0]])*100/len(stock_agg) # Check for outliers above Q3
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_12592\1924627882.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   len(stock_agg[stock_agg.Close>Q3['Close']+1.5*IQR[0]])*100/len(stock_agg) # Check for outliers above Q3
# 0.8333333333333334

# %%
stock_agg=stock_agg[stock_agg.Close<stock_agg.Close.quantile(.95)]  #change limit to 95%

# %%
len(stock_agg[stock_agg.Close>Q3['Close']+1.5*IQR[0]])*100/len(stock_agg)  #check for outliers above 95%
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_12592\1474479092.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   len(stock_agg[stock_agg.Close>Q3['Close']+1.5*IQR[0]])*100/len(stock_agg)  #check for outliers above 95%
# 0.0

# %%
len(stock_agg[stock_agg.Close<Q1['Close']-1.5*IQR[0]])*100/len(stock_agg) # Check for outliers below Q1
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_12592\3808264833.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   len(stock_agg[stock_agg.Close<Q1['Close']-1.5*IQR[0]])*100/len(stock_agg) # Check for outliers below Q1
# 0.0

# %% [markdown]
# #### Addressing outliers for 'Close'

# %%
len(stock_agg[stock_agg.Volume>Q3['Volume']+1.5*IQR[1]])*100/len(stock_agg)  # Check for outliers above Q3
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_12592\2480641463.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   len(stock_agg[stock_agg.Volume>Q3['Volume']+1.5*IQR[1]])*100/len(stock_agg)  # Check for outliers above Q3
# 4.385964912280702

# %%
stock_agg=stock_agg[stock_agg.Volume<stock_agg.Volume.quantile(.95)]  #change limit to 95%

# %%
plt.boxplot("Volume",data=stock_agg)   #Visualization
plt.xscale("log")

# %%
len(stock_agg[stock_agg.Volume<Q1['Volume']-1.5*IQR[1]])*100/len(stock_agg)  # Check for outliers below Q1
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_12592\1257414410.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   len(stock_agg[stock_agg.Volume<Q1['Volume']-1.5*IQR[1]])*100/len(stock_agg)  # Check for outliers below Q1
# 0.0

# %%
len(stock_agg[stock_agg.Volume>Q3['Volume']+1.5*IQR[1]])*100/len(stock_agg)
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_12592\3143394649.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   len(stock_agg[stock_agg.Volume>Q3['Volume']+1.5*IQR[1]])*100/len(stock_agg)
# 0.0

# %% [markdown]
# ## Prepare The Data for Modelling

# %%
from sklearn.model_selection import train_test_split

# %%
stock_final=stock_agg.drop(columns=["year","Month","yrmo"],axis=1)
stock_final.head()
# Out:
#    Close     Volume  Close_lag1  Close_lag2  Close_lag3  Close_lag4  \
# 1  21.80  334105560       21.16         NaN         NaN         NaN
# 4  21.19  297965736       22.69       22.03       21.80       21.16
# 5  21.83  334764900       21.19       22.69       22.03       21.80
# 6  25.70  280163556       21.83       21.19       22.69       22.03
# 7  26.52  248379372       25.70       21.83       21.19       22.69
#
#    Close_lag5  Close_lag6
# 1         NaN         NaN
# 4         NaN         NaN
# 5       21.16         NaN
# 6       21.80       21.16
# 7       22.03       21.80

# %% [markdown]
# ##### Normalize the data
#
#
# Note: we are using the z form ie, z=(x-E[x])/SD[x]

# %%
stock_n = stock_final.loc[:,stock_final.columns !='Close']
stock_n = (stock_n-stock_n.mean())/stock_n.std()  #standardization


#we can also do this directly via sci-kit module

# %%
stock_m=pd.concat([stock_n,stock_final.loc[:,'Close']],axis=1) #Concating the data to the esisting dataset
stock_m.head()
# Out:
#      Volume  Close_lag1  Close_lag2  Close_lag3  Close_lag4  Close_lag5  \
# 1  2.228621   -1.223709         NaN         NaN         NaN         NaN
# 4  1.670534   -1.173281   -1.189976   -1.173783   -1.158972         NaN
# 5  2.238803   -1.222720   -1.168136   -1.166192   -1.138308   -1.143672
# 6  1.395625   -1.201626   -1.217774   -1.144411   -1.130882   -1.123166
# 7  0.904800   -1.074073   -1.196595   -1.193914   -1.109573   -1.115796
#
#    Close_lag6  Close
# 1         NaN  21.80
# 4         NaN  21.19
# 5         NaN  21.83
# 6   -1.115134  25.70
# 7   -1.095232  26.52

# %%
stock_m.to_csv("Google_stock_prepared.csv",index=False)

# %%
X = stock_m.loc[:,stock_m.columns !="Close"] # all column except closing prince
Y = stock_m["Close"]   # only closing price column

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,random_state=42,test_size=0.2)  # randomn state-getting a shuffled dataset
print("length of the training data",len(X_train))
print("length of the test data",len(X_test))
print("length of the training Y",len(Y_train))
print("length of the test data",len(Y_test))
# Out:
# length of the training data 86
# length of the test data 22
# length of the training Y 86
# length of the test data 22
